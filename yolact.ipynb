# %% [markdown]
# # You Only Look At CoefficienTs

# %% [markdown]
# ## Environment setup

# %%
# GPU information
# !nvidia-smi

# Mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Tue Aug 23 05:50:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#==== change to custom path ====
# %cd /content/gdrive/MyDrive/NYCU/Activities/DYH/

# Clone the repository
# !git clone https://github.com/TW-yuhsi/Segmentation.git
# %cd Segmentation/yolact/
# %ll

# Install requirements
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda --version
# !which conda
import warnings
warnings.filterwarnings('ignore')
# %cd /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact/
# !conda env create -f environment.yml
# !conda activate yolact-env
# Cython needs to be installed before pycocotools
# !pip install cython
# !pip install opencv-python pillow pycocotools matplotlib
# !pip install -r requirements.txt
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
#%cd external/DCNv2
#!python setup.py build develop
# Out:
# /content/gdrive/MyDrive/NYCU/Activities/DYH
# Cloning into 'Segmentation'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 250 (delta 5), reused 0 (delta 0), pack-reused 225
# Receiving objects: 100% (250/250), 8.94 MiB | 12.63 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact
# total 147
# -rw------- 1 root 17286 Aug 23 05:51 backbone.py
# -rw------- 1 root  2933 Aug 23 05:51 CHANGELOG.md
# drwx------ 3 root  4096 Aug 23 05:51 data/
# -rw------- 1 root   928 Aug 23 05:51 environment.yml
# -rw------- 1 root 46915 Aug 23 05:51 eval.py
# drwx------ 3 root  4096 Aug 23 05:51 external/
# drwx------ 4 root  4096 Aug 23 05:51 layers/
# -rw------- 1 root  1069 Aug 23 05:51 LICENSE
# -rw------- 1 root    52 Aug 23 05:51 requirements.txt
# -rw------- 1 root  1416 Aug 23 05:51 run_coco_eval.py
# ...

# %% [markdown]
# ## Prepare weights (yolact/weights/)
# - [yolact_resnet50_54_800000.pth](https://drive.google.com/file/d/1yp7ZbbDwvMiFJEq4ptVKTYTI2VeRDXl0/view?usp=sharing)
# - [yolact_darknet53_54_800000.pth](https://drive.google.com/file/d/1dukLrTzZQEuhzitGkHaGjphlmRJOjVnP/view?usp=sharing)
# - [yolact_base_54_800000.pth](https://drive.google.com/file/d/1UYy3dMapbH1BnmtZU4WH1zbYgOzzHHf_/view?usp=sharing)
# - [yolact_im700_54_800000.pth](https://drive.google.com/file/d/1lE4Lz5p25teiXV-6HdTiOJSnS7u7GBzg/view?usp=sharing)
# - [yolact_plus_resnet50_54_800000.pth](https://drive.google.com/file/d/1ZPu1YR2UzGHQD0o1rEqy-j5bmEm3lbyP/view?usp=sharing)
# - [yolact_plus_base_54_800000.pth](https://drive.google.com/file/d/15id0Qq5eqRbkD-N3ZjDZXdCvRyIaHpFB/view?usp=sharing)

# %% [markdown]
# ## Inference

# %%
# %cd /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact/
# image
#==== change to custom path ====
# !python eval.py --trained_model=weights/yolact_im700_54_800000.pth --score_threshold=0.15 --top_k=15 --image=/content/gdrive/MyDrive/NYCU/Activities/DYH/yuhsi.jpg:/content/gdrive/MyDrive/NYCU/Activities/DYH/yuhsi_seg.jpg
# Out:
# /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact
# Config not specified. Parsed yolact_im700_config from the file name.
#
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'pred_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# Loading model... Done.

# %%
# %cd /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact/
# video
#==== change to custom path ====
# !python eval.py --trained_model=weights/yolact_im700_54_800000.pth --score_threshold=0.15 --top_k=15 --video_multiframe=4 --video=/content/gdrive/MyDrive/NYCU/Activities/DYH/video.mp4:/content/gdrive/MyDrive/NYCU/Activities/DYH/video_out.mp4
# Out:
# /content/gdrive/MyDrive/NYCU/Activities/DYH/Segmentation/yolact
# Config not specified. Parsed yolact_im700_config from the file name.
#
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'pred_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.7/site-packages/torch/jit/_recursive.py:239: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# Loading model... Done.
# ...
